# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
user_data = pd.read_csv("Analysis data.csv")
user_data.head()
# Out:
#           ResponseId                                            Trigger  \
# 0  R_2t9VfWrI4EnmkFI            mode is Away AND time is (after sunset)
# 1  R_2t9VfWrI4EnmkFI  mode is Away AND time is (after 10pm +- random...
# 2  R_2t9VfWrI4EnmkFI        temperature outside > 80 F AND mode is Away
# 3  R_2t9VfWrI4EnmkFI        temperature outside > 80 F AND mode is Home
# 4  R_2t9VfWrI4EnmkFI                 temperature < 50F AND mode is Away
#
#                                 Trigger Intermediate  \
# 0           location.mode=="away" &&  time=="sunset"
# 1             location.mode=="away" && time=="night"
# 2  e_temperature.temperatureMeasurement >80, mode...
# 3  e_temperature.temperatureMeasurement>80, mode=...
# 4       temp_sensor.temperature < 50, mode == "away"
#
#            Uniqueness Trigger  \
# 0             away and sunset
# 1              away and night
# 2  away and high temperature
# 3  home and high temperature
# 4    away and low temperature
#
#                          Full Uniqueness description  \
# 0               if (away and sunset) then (light on)
# 1               if (away and night) then (light off)
# 2  if (away and high temperature ) then (set ac a...
# 3      if (home and high temperature ) then (set ac)
# 4  if (away and low temperature) then (set thermo...
#
#                       Action Intermediate  \
# 0                           light_bulb.on
# 1                          light_bulb.off
# 2  ac.setLevel = 79; blind.switch = "off"
# 3                        ac.setLevel = 76
# 4      thermostat.setHeatingSetpoint = 55
#
#                                               Action  Unnamed: 7  \
# 0                           switch on the Light Bulb         NaN
# 1                          switch off the Light Bulb         NaN
# 2  set level of Air Conditioner to 79F AND close ...         NaN
# 3                set level of Air Conditioner to 76F         NaN
# 4           set heatingSetpoint of Thermostat to 55F         NaN
#
#                        Full Uniqueness description.1  \
# 0               if (away and sunset) then (light on)
# 1               if (away and night) then (light off)
# 2  if (away and high temperature ) then (set ac a...
# 3      if (home and high temperature ) then (set ac)
# 4  if (away and low temperature) then (set thermo...
#
#    Intersection: 0 = common; 1 = unique   \
# 0                                      0
# 1                                      0
# 2                                      1
# 3                                      0
# 4                                      0
#
#                                    Unnamed: 10       Unnamed: 11 note  \
# 0  Bright When Dark And/Or Bright After Sunset               NaN  NaN
# 1  Bright When Dark And/Or Bright After Sunset  Smart Nightlight  NaN
# 2                                          NaN               NaN  NaN
# 3                                 It's Too Hot               NaN  NaN
# 4                                 It's Too Hot               NaN  NaN
#
#   Unnamed: 13
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
unique_col = user_data[['Full Uniqueness description','Intersection: 0 = common; 1 = unique ']]
unique_col
# Out:
#                            Full Uniqueness description  \
# 0                 if (away and sunset) then (light on)
# 1                 if (away and night) then (light off)
# 2    if (away and high temperature ) then (set ac a...
# 3        if (home and high temperature ) then (set ac)
# 4    if (away and low temperature) then (set thermo...
# 5    if (home and low temperature) then (set thermo...
# 6        if (high temperature) then (fan on and ac on)
# 7       if (low temperature) then (fan off and ac off)
# 8    if (co_alarm on or gas_alarm on) then (securit...
# 9                  if (motion on) then (camera record)
# 10     if (low temperature) then (electric blanket on)
# 11   if (low temperature) then (ac mode heat and se...
# 12   if (high temperature) then (ac mode cool and s...
# 13                        if (wet) then (alarm strobe)
# 14                       if (smoke) then (alarm siren)
# 15                 if (doorbell ring) then (camera on)
# 16                      if (At night) then (lock door)
# 17                 if (glass break) then (alarm siren)
# 18                if (co level > 1) then (alarm siren)
# 19                       if (smoke) then (alarm siren)
# 20   if (winter and early in month and home) then (...
# 21            if (motion && night) then (notify phone)
# 22        if (high blood pressure) then (notify phone)
# 23   if (away) then (ac on and security camera on a...
# 24          if (away) then (switch off all appliances)
# 25                if (early morning) then (open shade)
# 26                      if (morning) then (open shade)
# 27                 if (rest of day) then (close shade)
# 28   if (home) then (ac on, robot on and oil warmer...
# 29             if (night) then (turn on sleep monitor)
# ..                                                 ...
# 171  if (morning and door open) then (open garage d...
# 172                            if (night) then (tv on)
# 173           if (sleeping) then (electric blanket on)
# 174        if (low air quality) then (air purifier on)
# 175    if (noon) then (robot vaccum on with mode auto)
# 176            if (home and morning) then (lights off)
# 177                        if (away) then (lights off)
# 178                  if (door is open) then (light on)
# 179    if (away and cooktop is on) then (notify phone)
# 180  if (not clean for a day) then (robot vaccum on...
# 181             if (low humidity) then (humidifier on)
# 182  if (high humidity and high temperature) then (...
# 183                  if (awake) then (coffee maker on)
# 184                         if (away) then (lock door)
# 185                    if (away) then (thermostat off)
# 186        if (low air quality) then (air purifier on)
# 187                    if (sleeping) then (lights off)
# 188    if (motion at door) then (lights on and notify)
# 189  if (morning) then (coffee maker on and open wi...
# 190  if (night) then (lock door, close garage door,...
# 191  if (away and alarm is on) then (notify, turn o...
# 192  if (vacation and morning) then (air cooler on,...
# 193  if (vacation and night) then (close shade, lig...
# 194  if (weather cold) then (notify phone and therm...
# 195  if (weather rain) then (notify phone, close do...
# 196  if (doorbell rings) then (unlock door and notify)
# 197          if (night and open) then (set alarm both)
# 198    if (high humidity) then (turn off smart mirror)
# 199  if (refrigerator door open) then (set alarm both)
# 200      if (doorbell rings) then (security camera on)
#
#      Intersection: 0 = common; 1 = unique
# 0                                        0
# 1                                        0
# 2                                        1
# 3                                        0
# 4                                        0
# 5                                        0
# 6                                        0
# 7                                        0
# 8                                        1
# 9                                        1
# 10                                       1
# 11                                       0
# 12                                       0
# 13                                       1
# 14                                       1
# 15                                       1
# 16                                       0
# 17                                       1
# 18                                       0
# 19                                       1
# 20                                       0
# 21                                       0
# 22                                       1
# 23                                       0
# 24                                       0
# 25                                       0
# 26                                       0
# 27                                       1
# 28                                       0
# 29                                       0
# ..                                     ...
# 171                                      1
# 172                                      0
# 173                                      1
# 174                                      1
# 175                                      0
# 176                                      0
# 177                                      0
# 178                                      1
# 179                                      1
# 180                                      1
# 181                                      0
# 182                                      0
# 183                                      1
# 184                                      0
# 185                                      0
# 186                                      1
# 187                                      1
# 188                                      0
# 189                                      0
# 190                                      0
# 191                                      1
# 192                                      1
# 193                                      1
# 194                                      1
# 195                                      1
# 196                                      1
# 197                                      1
# 198                                      0
# 199                                      1
# 200                                      1
#
# [201 rows x 2 columns]

# %%
len(unique_col)
# Out:
# 201

# %%
unique_col['Full Uniqueness description']
# Out:
# 0                   if (away and sunset) then (light on)
# 1                   if (away and night) then (light off)
# 2      if (away and high temperature ) then (set ac a...
# 3          if (home and high temperature ) then (set ac)
# 4      if (away and low temperature) then (set thermo...
# 5      if (home and low temperature) then (set thermo...
# 6          if (high temperature) then (fan on and ac on)
# 7         if (low temperature) then (fan off and ac off)
# 8      if (co_alarm on or gas_alarm on) then (securit...
# 9                    if (motion on) then (camera record)
# 10       if (low temperature) then (electric blanket on)
# 11     if (low temperature) then (ac mode heat and se...
# 12     if (high temperature) then (ac mode cool and s...
# 13                          if (wet) then (alarm strobe)
# 14                         if (smoke) then (alarm siren)
# 15                   if (doorbell ring) then (camera on)
# 16                        if (At night) then (lock door)
# 17                   if (glass break) then (alarm siren)
# 18                  if (co level > 1) then (alarm siren)
# 19                         if (smoke) then (alarm siren)
# 20     if (winter and early in month and home) then (...
# 21              if (motion && night) then (notify phone)
# 22          if (high blood pressure) then (notify phone)
# 23     if (away) then (ac on and security camera on a...
# 24            if (away) then (switch off all appliances)
# 25                  if (early morning) then (open shade)
# 26                        if (morning) then (open shade)
# 27                   if (rest of day) then (close shade)
# 28     if (home) then (ac on, robot on and oil warmer...
# 29               if (night) then (turn on sleep monitor)
#                              ...
# 171    if (morning and door open) then (open garage d...
# 172                              if (night) then (tv on)
# 173             if (sleeping) then (electric blanket on)
# 174          if (low air quality) then (air purifier on)
# 175      if (noon) then (robot vaccum on with mode auto)
# 176              if (home and morning) then (lights off)
# 177                          if (away) then (lights off)
# 178                    if (door is open) then (light on)
# 179      if (away and cooktop is on) then (notify phone)
# 180    if (not clean for a day) then (robot vaccum on...
# 181               if (low humidity) then (humidifier on)
# 182    if (high humidity and high temperature) then (...
# 183                    if (awake) then (coffee maker on)
# 184                           if (away) then (lock door)
# 185                      if (away) then (thermostat off)
# 186          if (low air quality) then (air purifier on)
# 187                      if (sleeping) then (lights off)
# 188      if (motion at door) then (lights on and notify)
# 189    if (morning) then (coffee maker on and open wi...
# 190    if (night) then (lock door, close garage door,...
# 191    if (away and alarm is on) then (notify, turn o...
# 192    if (vacation and morning) then (air cooler on,...
# 193    if (vacation and night) then (close shade, lig...
# 194    if (weather cold) then (notify phone and therm...
# 195    if (weather rain) then (notify phone, close do...
# 196    if (doorbell rings) then (unlock door and notify)
# 197            if (night and open) then (set alarm both)
# 198      if (high humidity) then (turn off smart mirror)
# 199    if (refrigerator door open) then (set alarm both)
# 200        if (doorbell rings) then (security camera on)
# Name: Full Uniqueness description, Length: 201, dtype: object

# %%
unique_routine = []
common_total = 0
for index in range(len(unique_col)):
    if unique_col['Full Uniqueness description'][index] not in unique_routine:
        unique_routine.append(unique_col['Full Uniqueness description'][index])
        if unique_col['Intersection: 0 = common; 1 = unique '][index] == 1:
            common_total+=1

# unique_routine

# %%
common_total
# Out:
# 82

# %%
all_triggers = user_data['Uniqueness Trigger'].dropna().values
all_triggers
# Out:
# array(['away and sunset', 'away and night', 'away and high temperature ',
#        'home and high temperature ', 'away and low temperature',
#        'home and low temperature', 'high temperature', 'low temperature',
#        'co_alarm on or gas_alarm on', 'motion on', 'low temperature',
#        'low temperature', 'high temperature', 'wet', 'smoke',
#        'doorbell ring', 'At night', 'glass break', 'co level > 1', 'smoke',
#        'winter and early in month and home', 'motion && night',
#        'high blood pressure', 'away', 'away', 'early morning', 'morning',
#        'rest of day', 'home', 'night', 'low temperature',
#        'high pulse rate', 'motion or glass break',
#        'smoke or co or water leak', 'night', 'vacation', 'bathroom motion',
#        'smart printer idle', 'low battery in smoke detector',
#        'smoke detector is tampered', 'doorbell ring', 'away and light on',
#        'midnight and ac on', 'away', 'home', 'midnight', 'detected co',
#        'away', 'doorbell ring', 'morning and no rain',
#        'energy more than average', 'away and door is unlocked',
#        'glass break', 'vacation', 'sensed gas', 'water leak',
#        'dryer running and high temperature', 'low temperature',
#        'night and low temperature in electric blanket',
#        'night and after 9pm', 'morning', 'afternoon', 'high ordorLevel',
#        'low ordorLevel', 'high humidity', 'smoke and high temperature',
#        'smoke detector is tampered', 'low battery in smoke detector',
#        'low air quality', 'high air quality',
#        'low temperature during the day and sleeping time',
#        'morning and weekday', 'presence and open garage door',
#        'glass break', 'motion', 'high ordorLevel',
#        'enters room and no light', 'no motion in room and lights on',
#        'detect device nearby in living room',
#        'did not detect nearby in living room',
#        'detect device nearby in kitchen',
#        'did not detect nearby in kitchen', 'detect device nearby in home',
#        'home', 'did not detect nearby in home', 'away', 'sunset',
#        'bedroom button pressed', 'night', 'alarm time',
#        'detected car nearby', 'low signal strength in garage door opener',
#        'morning', 'high coffee maker temperature', 'high temperature',
#        'low temperature', 'smoke', 'pressed a button', 'pressed a button',
#        'low light', 'high light',
#        'refrigerator water filter status "replace"', 'home and night',
#        'high or low temperature', 'normal temperature', 'smart tv is on',
#        'no one is at home', 'glass break', 'when someone is sleeping',
#        'when the house detects smoke or gas or high moisture content',
#        'water leak', 'high temperature', 'not too hot and volume < 10',
#        'morning', 'night', 'gas stove running with 20 min left',
#        'gas stove running with a timer or temp is 180',
#        'low refrigerator temperature',
#        'gas stove running with 20 min left', 'dry', 'wet',
#        'reached certain time', 'low air quality', 'low light and motion',
#        'no one is at home for 24 hours', 'low temperature',
#        'high temperature',
#        'door is unlocked during night or no one is home for more than 1 hour',
#        'no presence for an hour',
#        'blind is closed during day and no motion', 'away and door opens',
#        'home and door opens', 'home and sound', 'high temperature',
#        'high temperature', 'high humidity', 'night and low light',
#        'low temperature or high temperature', 'weekend and at 2pm',
#        'morning', 'night', 'high temperature and not in vacation',
#        'low temperature and not in vacation', 'morning and weekday',
#        'afternoon and weekday',
#        'vacation and gas detected or wet or co detected ',
#        'not vacation and gas detected or wet or co detected ',
#        'vacation and during March to September', 'away and door open',
#        'vacation and door open and shock',
#        'not raining and in winter afternoon', 'no motion',
#        'high or low blood pressure', 'high dust level', 'sleeping',
#        'high temperature', 'high temperature', 'cloth wet', 'morning',
#        'night', 'night and summer', 'dish in dishwasher', 'wet',
#        'night and low temperature', 'night and high temperature',
#        'dryer complete', 'away and door is in unlock mode',
#        'away and garage door is open', 'morning', 'awake', 'awake',
#        'morning and door open', 'night', 'sleeping', 'low air quality',
#        'noon', 'home and morning', 'away', 'door is open',
#        'away and cooktop is on', 'not clean for a day', 'low humidity',
#        'high humidity and high temperature', 'awake', 'away', 'away',
#        'low air quality', 'sleeping', 'motion at door', 'morning', 'night',
#        'away and alarm is on', 'vacation and morning',
#        'vacation and night', 'weather cold', 'weather rain',
#        'doorbell rings', 'night and open', 'high humidity',
#        'refrigerator door open', 'doorbell rings'], dtype=object)

# %%
unique_triggers =[]
for triggers in all_triggers:
    if triggers not in unique_triggers:
        unique_triggers.append(triggers)

len(unique_triggers)
# Out:
# 137
